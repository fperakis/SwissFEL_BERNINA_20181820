# %% [markdown]
# # Loads the processed h5 file and plots data

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import h5py
import time
import sys

# %%
run = '0011_jet10um_RT'
h5path = '/sf/bernina/data/p17743/res/work/hdf5/run%s.h5'%run
h5file = h5py.File(h5path,'r')

# %%
img = h5file['JF7/2D_sum']
q  = h5file['JF7/Q_bins']
Iq = h5file['JF7/I_Q'] 
i0 = h5file['JF7/i0'] 
nshots = h5file['JF7/num_shots'].value

# %%
plt.figure()
plt.title('Average 2D image')
plt.imshow(img2d/nshots,clim=[0,10],origin='lower')
plt.colorbar()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure(figsize=[7,7])

plt.subplot(2,1,1)
plt.imshow(Iq,aspect='auto')
plt.title('Angular integration')
plt.xlabel('Q bin')
plt.ylabel('shot number')
plt.colorbar()

plt.subplot(2,1,2)
plt.title('Average')
plt.plot(np.average(Iq,axis=0))
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
plt.figure(figsize=[8,3])
plt.subplot(1,2,1)
plt.plot(i0)
plt.xlabel('shot number')
plt.ylabel('i0')
plt.xlim([0,100])


plt.subplot(1,2,2)
bi,bf,db = 2,100,1
bins = np.arange(bi-db,bf+db,db)
hy,hx = np.histogram(i0,bins=bins)
plt.plot(hx[1:]-1,hy)
plt.tight_layout()
plt.ylabel('shot number')
plt.xlabel('i0')
#plt.xlim(10,50)
plt.tight_layout()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
